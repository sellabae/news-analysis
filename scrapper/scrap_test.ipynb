# %%
import requests
from bs4 import BeautifulSoup
import lxml

import os
import datetime as dt
from datetime import datetime
import pandas as pd
import re

# local time
print('local', datetime.now())
# 현재 한국 시간
KST = dt.timezone(dt.timedelta(hours=9)) #korean timezone utc+9
now = datetime.now(tz=KST)
print('korea', now)

# 저장될 데이터프레임 준비
cols = ['date','category','title','link','author']
# df = pd.DataFrame(columns=cols)

# 저장될 폴더&파일 준비
dirpath = 'scrapped/'
if not os.path.exists(dirpath):
    os.makedirs(dirpath)
fpath = dirpath + 'hani_{0}.csv'.format(now.strftime('%Y-%m-%d_%H:%M:%S'))
with open(fpath, 'w') as f:
    f.write(','.join(cols) + '\n')
# Out:
# local 2020-05-08 04:26:19.524212
# korea 2020-05-08 20:26:19.524580+09:00

# %%
# 한겨레 현재시간 전체기사 base url
home_url = "http://www.hani.co.kr"
base_url = "http://www.hani.co.kr/arti/"

# 한 페이지 내 기사목록 스크랩
def get_articles_hani(url):
    # Gets page
    res = requests.get(url)
    if not res.ok:
        print('Request fails. url:', url)
        return
    
    print('Getting articles from', url)
    df = pd.DataFrame(columns=cols)
    
    soup = BeautifulSoup(res.text, 'lxml')
    
    article_list = soup.select('div.article-area')
    # Extracts article details
    for article in article_list:
        at = article.select('.article-title a')[0]
        link = home_url + at.get('href')
        title = at.text
        category = article.select('.category a')[0].text
        datestr = article.select('.date')[0].text
        date = datetime.strptime(datestr, '%Y-%m-%d %H:%M')
        #add all to dataframe
        df.loc[len(df)] = [date,category,title,link,'']
        
    return df

# 페이지별 반복
for i in range(30):
    end_url = "list{0}.html".format(i+1)
    df = get_articles_hani(base_url + end_url)
    df.to_csv(fpath, mode='a', header=False, index=False)
# Out:
# Getting articles from http://www.hani.co.kr/arti/list1.html
# Getting articles from http://www.hani.co.kr/arti/list2.html
# Getting articles from http://www.hani.co.kr/arti/list3.html
# Getting articles from http://www.hani.co.kr/arti/list4.html
# Getting articles from http://www.hani.co.kr/arti/list5.html
# Getting articles from http://www.hani.co.kr/arti/list6.html
# Getting articles from http://www.hani.co.kr/arti/list7.html
# Getting articles from http://www.hani.co.kr/arti/list8.html
# Getting articles from http://www.hani.co.kr/arti/list9.html
# Getting articles from http://www.hani.co.kr/arti/list10.html
# Getting articles from http://www.hani.co.kr/arti/list11.html
# Getting articles from http://www.hani.co.kr/arti/list12.html
# Getting articles from http://www.hani.co.kr/arti/list13.html
# Getting articles from http://www.hani.co.kr/arti/list14.html
# Getting articles from http://www.hani.co.kr/arti/list15.html
# Getting articles from http://www.hani.co.kr/arti/list16.html
# Getting articles from http://www.hani.co.kr/arti/list17.html
# Getting articles from http://www.hani.co.kr/arti/list18.html
# Getting articles from http://www.hani.co.kr/arti/list19.html
# Getting articles from http://www.hani.co.kr/arti/list20.html
# Getting articles from http://www.hani.co.kr/arti/list21.html
# Getting articles from http://www.hani.co.kr/arti/list22.html
# Getting articles from http://www.hani.co.kr/arti/list23.html
# Getting articles from http://www.hani.co.kr/arti/list24.html
# Getting articles from http://www.hani.co.kr/arti/list25.html
# Getting articles from http://www.hani.co.kr/arti/list26.html
# Getting articles from http://www.hani.co.kr/arti/list27.html
# Getting articles from http://www.hani.co.kr/arti/list28.html
# Getting articles from http://www.hani.co.kr/arti/list29.html
# Getting articles from http://www.hani.co.kr/arti/list30.html

# %%
# Read and check the saved file
pd.read_csv(fpath)
# Out:
#                     date         category  \
# 0    2020-05-08 18:57:00               사회
# 1    2020-05-08 18:54:00               문화
# 2    2020-05-08 18:54:00               문화
# 3    2020-05-08 18:45:00            사설.칼럼
# 4    2020-05-08 18:39:00            사설.칼럼
# 5    2020-05-08 18:37:00               정치
# 6    2020-05-08 18:34:00               사회
# 7    2020-05-08 18:30:00               사회
# 8    2020-05-08 18:25:00  English Edition
# 9    2020-05-08 18:22:00  English Edition
# 10   2020-05-08 18:17:00  English Edition
# 11   2020-05-08 18:17:00               전국
# 12   2020-05-08 18:16:00  English Edition
# 13   2020-05-08 18:13:00  English Edition
# 14   2020-05-08 18:12:00               경제
# 15   2020-05-08 18:11:00  English Edition
# 16   2020-05-08 18:02:00               사회
# 17   2020-05-08 17:52:00               사회
# 18   2020-05-08 17:49:00  English Edition
# 19   2020-05-08 17:47:00            사설.칼럼
# 20   2020-05-08 17:44:00  English Edition
# 21   2020-05-08 17:32:00               사회
# 22   2020-05-08 17:28:00               문화
# 23   2020-05-08 17:22:00            사설.칼럼
# 24   2020-05-08 17:20:00            사설.칼럼
# 25   2020-05-08 17:18:00            사설.칼럼
# 26   2020-05-08 17:02:00               정치
# 27   2020-05-08 16:52:00              ESC
# 28   2020-05-08 16:51:00              ESC
# 29   2020-05-08 16:50:00              ESC
# ..                   ...              ...
# 420  2020-05-06 12:08:00               사회
# 421  2020-05-06 12:00:00               경제
# 422  2020-05-06 12:00:00               경제
# 423  2020-05-06 12:00:00               국제
# 424  2020-05-06 11:57:00               전국
# 425  2020-05-06 11:55:00               정치
# 426  2020-05-06 11:50:00               전국
# 427  2020-05-06 11:48:00               전국
# 428  2020-05-06 11:48:00               경제
# 429  2020-05-06 11:46:00               전국
# 430  2020-05-06 11:46:00               전국
# 431  2020-05-06 11:45:00               전국
# 432  2020-05-06 11:35:00               경제
# 433  2020-05-06 11:18:00               경제
# 434  2020-05-06 11:13:00               전국
# 435  2020-05-06 11:11:00            사설.칼럼
# 436  2020-05-06 11:09:00               정치
# 437  2020-05-06 11:09:00               사회
# 438  2020-05-06 10:59:00               경제
# 439  2020-05-06 10:59:00               정치
# 440  2020-05-06 10:56:00               전국
# 441  2020-05-06 10:46:00               문화
# 442  2020-05-06 10:46:00               전국
# 443  2020-05-06 10:42:00               전국
# 444  2020-05-06 10:32:00            미래&과학
# 445  2020-05-06 10:30:00               사회
# 446  2020-05-06 10:17:00               사회
# 447  2020-05-06 10:13:00               정치
# 448  2020-05-06 10:07:00               경제
# 449  2020-05-06 09:57:00              스포츠
#
#                                                  title  \
# 0                      이용수 할머니는 왜 ‘30년 동행’ 수요집회를 비판했을까
# 1                            올해를 ‘방탄 콘서트’ 없이 보낼 수는 없어…
# 2                     [주말 본방사수] 아픈 아이와 그를 돌보는 아빠의 ‘동행’
# 3                      [사설] 느슨해진 분위기에 경고등 울린 ‘클럽 집단감염’
# 4                   [사설] ‘조국 사건’ 진실 찾기, ‘법원의 시간’에 주목한다
# 5                            대전현충원 전두환 친필 현판, 안중근체로 교체
# 6                                             5월 9일 인사
# 7                                          5월 9일 궂긴 소식
# 8    S. Korea announces major projects and goals of...
# 9    US demands 50% increase in S. Korea’s defense ...
# 10   S. Korean unification minister emphasizes impo...
# 11                         자가격리중 무단이탈해 일본가려던 40대 여성 잡혀
# 12   JCS misreported effective range of N. Korean a...
# 13   [Reportage] Vietnamese migrant worker banned f...
# 14                    시총 6위 셀트리온 1분기 영업익 1202억원…55.4%↑
# 15   Imported of British sanitary pads falsely adve...
# 16                  고용노동부, “대법원에 ‘산재 사망’ 사업주 양형 강화 요청”
# 17               대학 70% ‘1학기 전체’ 또는 ‘코로나 안정기까지’ 온라인 강의
# 18   Samsung’s legal oversight committee requests m...
# 19               [사설] 통합당 주호영 원내대표, ‘혁신’ 없인 ‘당 재건’도 없다
# 20   2 confirmed COVID-19 patients visited multiple...
# 21                    사이버사령부 하사 코로나 확진…지침 어기고 이태원클럽 방문
# 22                         ‘여혐 논란’ 정영진, MBC ‘싱글벙글쇼’ 하차
# 23                                  [탁기형의 비어 있는 풍경] 선택
# 24                          [크리틱] 온라인 콘서트, 안전한가요? / 미묘
# 25                        [삶의 창] 나의 심장을 부수려고 돌아온 / 이명석
# 26                         ‘국민발안제 개헌안’ 통합당 불참으로 투표 불성립
# 27                               [ESC] 거절의 펀치를 견뎌내는 방법
# 28                           [ESC] 계단이 만든 1~2m 높이차의 비밀
# 29                              [ESC] 누에는 뽕잎을 먹으러 떠납니다
# ..                                                 ...
# 420           부모 나라 가본 적 없는 ‘미등록 이주아동’…인권위 “강제퇴거 중단하라”
# 421                        지난해 줄었던 불법 사금융 피해 올들어 다시 급증
# 422                     코엑스, 이달까지 취소된 전시회 임대료 60% 돌려준다
# 423                 영국 ‘봉쇄령’ 자문한 교수, 봉쇄령 어기고 여친 만났다 사퇴
# 424              경기야 살아라…‘굿 바이(bye) 코로나, 굿 바이(buy) 충북’
# 425                   한미 외교장관 통화, 코로나19·방위비·북한 동향 등 논의
# 426                        완주 삼례여중 축구부의 ‘기적’ 스크린서 재연된다
# 427                   군산 앞바다서 해삼 1300만원어치 불법 채취한 일당 적발
# 428                  온라인 유통·교육 비대면 ‘기회산업’…포스트 코로나 산업전략
# 429                      목포역·강진농고·신북장터 등 전남 25곳 사적지 지정
# 430                                 제주4·3 트라우마센터 6일 개소
# 431                    제주도, ’전국 최초 등교생 사전검사’ 섣부른 발표 망신
# 432                        기재부, 내년 정부 부처 재량지출 10% 구조조정
# 433                   코로나19 취업 한파 닥쳤던 3월 청년층 대출 연체율 급증
# 434                 파키스탄서 입국한 30대 확진…충북 34일 만에 46번째 발생
# 435                                      [공감세상] 죽음의 숫자
# 436                             올해 사관학교 생도 선발 일정 3주 순연
# 437                     재심 ‘무죄’ 고 조영래 변호사 유족에 1억원 국가배상
# 438                       왕홍이 틱톡으로 국내 마스크팩 홍보…K스튜디오 개설
# 439                   해군 전 함정 ‘생큐’ 깃발 게양, ‘덕분에 챌린지’ 동참
# 440                      울산시, 공유경제 첫 사업으로 '공유주방' 직접 운영
# 441                   BTS, 오바마 전 미 대통령과 ‘온라인 졸업식’ 축사한다
# 442                     제도권 금융이용 어려운 인천시민에 최대 300만원 대출
# 443                      ‘소방차 출동시간 단축’ 고안한 소방관 근정포장 수상
# 444                                 눈폭풍에 맞서…공처럼 웅크린 토끼
# 445                 또 수입차 배출가스 불법조작 적발…벤츠·닛산·포르쉐 등 14종
# 446                 [속보] 코로나19 환자 2명 늘어…누적 환자 수 1만806명
# 447                     김태흠 “부덕의 소치” 통합당 원내대표 선거 출마 접어
# 448                               신보, ‘혁신아이콘’ 5개 기업 선정
# 449                     대만 프로야구 “이르면 8일부터 관중 1000명 허용”
#
#                                                   link  reporter
# 0    http://www.hani.co.kr/arti/society/society_gen...       NaN
# 1    http://www.hani.co.kr/arti/culture/culture_gen...       NaN
# 2    http://www.hani.co.kr/arti/culture/culture_gen...       NaN
# 3    http://www.hani.co.kr/arti/opinion/editorial/9...       NaN
# 4    http://www.hani.co.kr/arti/opinion/editorial/9...       NaN
# 5    http://www.hani.co.kr/arti/politics/defense/94...       NaN
# 6    http://www.hani.co.kr/arti/society/internalmov...       NaN
# 7    http://www.hani.co.kr/arti/society/obituary/94...       NaN
# 8    http://www.hani.co.kr/arti/english_edition/e_b...       NaN
# 9    http://www.hani.co.kr/arti/english_edition/e_i...       NaN
# 10   http://www.hani.co.kr/arti/english_edition/e_n...       NaN
# 11   http://www.hani.co.kr/arti/area/honam/944204.html       NaN
# 12   http://www.hani.co.kr/arti/english_edition/e_n...       NaN
# 13   http://www.hani.co.kr/arti/english_edition/e_i...       NaN
# 14   http://www.hani.co.kr/arti/economy/marketing/9...       NaN
# 15   http://www.hani.co.kr/arti/english_edition/e_b...       NaN
# 16   http://www.hani.co.kr/arti/society/labor/94419...       NaN
# 17   http://www.hani.co.kr/arti/society/schooling/9...       NaN
# 18   http://www.hani.co.kr/arti/english_edition/e_b...       NaN
# 19   http://www.hani.co.kr/arti/opinion/editorial/9...       NaN
# 20   http://www.hani.co.kr/arti/english_edition/e_n...       NaN
# 21   http://www.hani.co.kr/arti/society/society_gen...       NaN
# 22   http://www.hani.co.kr/arti/culture/culture_gen...       NaN
# 23   http://www.hani.co.kr/arti/opinion/column/9441...       NaN
# 24   http://www.hani.co.kr/arti/opinion/column/9441...       NaN
# 25   http://www.hani.co.kr/arti/opinion/column/9441...       NaN
# 26   http://www.hani.co.kr/arti/politics/assembly/9...       NaN
# 27   http://www.hani.co.kr/arti/specialsection/esc_...       NaN
# 28   http://www.hani.co.kr/arti/specialsection/esc_...       NaN
# 29   http://www.hani.co.kr/arti/specialsection/esc_...       NaN
# ..                                                 ...       ...
# 420  http://www.hani.co.kr/arti/society/society_gen...       NaN
# 421  http://www.hani.co.kr/arti/economy/finance/943...       NaN
# 422  http://www.hani.co.kr/arti/economy/marketing/9...       NaN
# 423  http://www.hani.co.kr/arti/international/inter...       NaN
# 424  http://www.hani.co.kr/arti/area/chungcheong/94...       NaN
# 425  http://www.hani.co.kr/arti/politics/diplomacy/...       NaN
# 426  http://www.hani.co.kr/arti/area/honam/943779.html       NaN
# 427  http://www.hani.co.kr/arti/area/honam/943778.html       NaN
# 428  http://www.hani.co.kr/arti/economy/marketing/9...       NaN
# 429  http://www.hani.co.kr/arti/area/honam/943776.html       NaN
# 430   http://www.hani.co.kr/arti/area/jeju/943775.html       NaN
# 431   http://www.hani.co.kr/arti/area/jeju/943774.html       NaN
# 432  http://www.hani.co.kr/arti/economy/economy_gen...       NaN
# 433  http://www.hani.co.kr/arti/economy/economy_gen...       NaN
# 434  http://www.hani.co.kr/arti/area/chungcheong/94...       NaN
# 435  http://www.hani.co.kr/arti/opinion/column/9437...       NaN
# 436  http://www.hani.co.kr/arti/politics/defense/94...       NaN
# 437  http://www.hani.co.kr/arti/society/society_gen...       NaN
# 438  http://www.hani.co.kr/arti/economy/marketing/9...       NaN
# 439  http://www.hani.co.kr/arti/politics/defense/94...       NaN
# 440  http://www.hani.co.kr/arti/area/yeongnam/94376...       NaN
# 441  http://www.hani.co.kr/arti/culture/entertainme...       NaN
# 442  http://www.hani.co.kr/arti/area/capital/943763...       NaN
# 443  http://www.hani.co.kr/arti/area/capital/943762...       NaN
# 444  http://www.hani.co.kr/arti/science/future/9437...       NaN
# 445  http://www.hani.co.kr/arti/society/environment...       NaN
# 446  http://www.hani.co.kr/arti/society/health/9437...       NaN
# 447  http://www.hani.co.kr/arti/politics/assembly/9...       NaN
# 448  http://www.hani.co.kr/arti/economy/finance/943...       NaN
# 449  http://www.hani.co.kr/arti/sports/baseball/943...       NaN
#
# [450 rows x 5 columns]

# %%
selector_hani = {'article':'div.article-area',
                 'title':'.article-title a',
                 'category':'.category a',
                 'date':'.date',
                 'author':None}

selector_chos = {'article':'dl.list_item',
                 'title':'dt a',
                 'category':None,
                 'date':'.date',
                 'author':'.author'}

# %%
# 조선일보 일자별 '전체기사' 스크랩

def get_articles_chos(url, selector, verbose=1):
    # Gets page
    res = requests.get(url)
    res.encoding = 'UTF-8'
    if not res.ok:
        print('Request fails. url:', url)
        return None
    
    if verbose > 0 : print('Getting articles from', url) #print this page
    df = pd.DataFrame(columns=cols)
    soup = BeautifulSoup(res.text, 'lxml')
    
    article_list = soup.select(selector['article'])
    # Extracts article details
    for article in article_list:
        at = article.select(selector['title'])[0]
        link = "https:" + at.get('href')                            #기사링크
        title = at.text                                             #제목
#         category = article.select(selector['category'])[0].text   #분류
        datestr = article.select(selector['date'])[0].text
        datestr = re.sub("\s\(\w*\)$", "", datestr)
        date = datetime.strptime(datestr, '%Y.%m.%d')               #날짜
        try:
            author = article.select(selector['author'])[0].text         #작성자
            author = author.replace('\n','').strip().replace(' 기자','') #문자열 정리
        except:
            author = ''
        #add all to dataframe
        df.loc[len(df)] = [date,'',title,link,author]
        if verbose > 2: print('','',title,link,author) #print this row
        
    return df


# 해당일 전체기사 가져오기
def chos_get_articles_oneday(date, verbose=1):
    if date.date() >= now.replace(tzinfo=None).date():
        print("Not {0} yet.".format(date.date()))
        return
    
    print('\nGet all articles on the day', date.date())
    
    # 조선일보 특정일 전체기사 base url
    datestr = date.strftime('%Y%m%d')
    base_url = "https://news.chosun.com/svc/list_in/list.html?indate={0}".format(datestr)
    print('BaseURL:', base_url)
    
    fpath = dirpath + 'chos_{0}.csv'.format(datestr)
    with open(fpath, 'w') as f:
        f.write(','.join(cols) + '\n')

    # 해당일자 전체기사 페이지 전체 반복
    i = 1
    while True:
        page_url = base_url + "&pn={0}".format(i)
        df = get_articles_chos(page_url, selector=selector_chos, verbose=verbose)
        if df.empty:
            break
        df.to_csv(fpath, mode='a', header=False, index=False)
        i += 1
    print("Checked through {0} pages".format(i))
    print("Saved articles in '{0}'".format(fpath))
    

# 일정기간 중 전체기사 가져오기
def chos_get_articles_days(startdate, days=7, verbose=1):
    enddate = startdate+dt.timedelta(days=days-1)
    print('Fetch articles from {0} to {1}. {2} days.'.format(
        startdate.date(), enddate.date(), days))
    
    for i in range(days):
        date = startdate + dt.timedelta(days=i)
        chos_get_articles_oneday(date, verbose=verbose)

# %%
# chos_get_articles_oneday(datetime.strptime('2020-04-27','%Y-%m-%d'), verbose=0)
chos_get_articles_days(datetime.strptime('2020-04-27','%Y-%m-%d'),
                       days=7,
                       verbose=0)
# chos_get_articles_days(datetime.strptime('2020-05-04','%Y-%m-%d'),
#                        days=7,
#                        verbose=0)
# Out:
# Fetch articles from 2020-05-09 to 2020-05-15. 7 days.
# Not 2020-05-09 yet.
# Not 2020-05-10 yet.
# Not 2020-05-11 yet.
# Not 2020-05-12 yet.
# Not 2020-05-13 yet.
# Not 2020-05-14 yet.
# Not 2020-05-15 yet.
